# %% [markdown]
# ## The plan
#
# 1. Autoencoder architecture - go over:
#
#     Architecture seems fine
#
# 2. Data sampling - go over the way we do it
#
#     Also seems correct - we take every graph and break it down to 100 subgraphs
#     Perheps we shouldnt. maybe we should create inifinate dataloaders at size, where every subgraph has at least 1000 nodes?
#
# 3. Training - revise the training method, specifically the cosing simillarity part
